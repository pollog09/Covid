# %% [markdown]
# ## Descarga del Dataset de Covid

# %%
import kagglehub
import shutil


# Download the dataset (default download path will be in /root/.kagglehub)
path = kagglehub.dataset_download("pranavraikokte/covid19-image-dataset")

# Specify the destination path in Google Drive
save_path = "dataset"

# Move the downloaded dataset to the specified path in Google Drive
shutil.move(path, save_path)

print("Dataset successfully moved to:", save_path)
# Out:
# Dataset successfully moved to: dataset

# %% [markdown]
# ### Filtro Blur / Sober / Canny
# > No usar ( Usar los siguientes bloques de codigo)

# %%
import cv2
import os
import numpy as np

input_folder = 'dataset/Covid19-dataset/train'
output_folder = 'dataset/output/filters'

# Crear la carpeta de salida si no existe
os.makedirs(output_folder, exist_ok=True)

# Procesar cada imagen en la carpeta de entrada
for folder in os.listdir(input_folder):
    folder_path = os.path.join(input_folder, folder)
    output_folder_path = os.path.join(output_folder, folder)
    os.makedirs(output_folder_path, exist_ok=True)
    
    if os.path.isdir(folder_path):
        for image_name in os.listdir(folder_path):
            image_path = os.path.join(folder_path, image_name)
            
            # Debug: Print the image path
            print(f"Processing image: {image_path}")

            # Leer la imagen
            image = cv2.imread(image_path)

            if image is None:
                print(f"No se pudo leer la imagen: {image_name}")
                continue

            # Aplicar Blur Filter
            blur = cv2.GaussianBlur(image, (15, 15), 0)

            # Aplicar Sobel Edge Detection
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convertir a escala de grises
            sobel_x = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3)
            sobel_y = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3)
            sobel = cv2.magnitude(sobel_x, sobel_y)
            sobel = cv2.convertScaleAbs(sobel)  # Convertir para visualizar

            # Aplicar Canny Edge Detection
            canny = cv2.Canny(gray, 100, 200)

            # Guardar las imágenes procesadas
            blur_path = os.path.join(output_folder_path, f"blur_{image_name}")
            sobel_path = os.path.join(output_folder_path, f"sobel_{image_name}")
            canny_path = os.path.join(output_folder_path, f"canny_{image_name}")

            cv2.imwrite(blur_path, blur)
            cv2.imwrite(sobel_path, sobel)
            cv2.imwrite(canny_path, canny)

            print(f"Processed and saved: {image_name}")
# Out:
# Processing image: dataset/2/Covid19-dataset/train\Covid\01.jpeg
# Processed and saved: 01.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\010.png
# Processed and saved: 010.png
# Processing image: dataset/2/Covid19-dataset/train\Covid\012.jpeg
# Processed and saved: 012.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\015.jpg
# Processed and saved: 015.jpg
# Processing image: dataset/2/Covid19-dataset/train\Covid\019.png
# Processed and saved: 019.png
# Processing image: dataset/2/Covid19-dataset/train\Covid\02.jpeg
# Processed and saved: 02.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\020.jpg
# Processed and saved: 020.jpg
# Processing image: dataset/2/Covid19-dataset/train\Covid\021.jpeg
# Processed and saved: 021.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\022.jpeg
# Processed and saved: 022.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\024.jpeg
# Processed and saved: 024.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\025.jpeg
# Processed and saved: 025.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\026.jpeg
# Processed and saved: 026.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\027.jpeg
# Processed and saved: 027.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\03.jpeg
# Processed and saved: 03.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\031.jpeg
# Processed and saved: 031.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\032.jpeg
# Processed and saved: 032.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\033.png
# Processed and saved: 033.png
# Processing image: dataset/2/Covid19-dataset/train\Covid\039.jpeg
# Processed and saved: 039.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\04.png
# Processed and saved: 04.png
# Processing image: dataset/2/Covid19-dataset/train\Covid\040.jpeg
# Processed and saved: 040.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\041.jpeg
# Processed and saved: 041.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid\042.jpeg
# Processed and saved: 042.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Covid
jpeg
# Processing image: dataset/2/Covid19-dataset/train\Viral Pneumonia\082.jpeg
# Processed and saved: 082.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Viral Pneumonia\083.jpeg
# Processed and saved: 083.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Viral Pneumonia\084.jpeg
# Processed and saved: 084.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Viral Pneumonia\09.jpeg
# Processed and saved: 09.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Viral Pneumonia\094.jpeg
# Processed and saved: 094.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Viral Pneumonia\095.jpeg
# Processed and saved: 095.jpeg
# Processing image: dataset/2/Covid19-dataset/train\Viral Pneumonia\096.jpeg
# Processed and saved: 096.jpeg

# %% [markdown]
# ## Preparacion de las imagenes con filtro bilateral

# %%
import os
import cv2

# Crear la carpeta de salida si no existe
input_folder = 'dataset/Covid19-dataset'
bilateral_output_folder = 'dataset/output/bilateral'
os.makedirs(bilateral_output_folder, exist_ok=True)

# Procesar cada imagen en la carpeta de entrada
for root, dirs, files in os.walk(input_folder):
    for file in files:
        image_path = os.path.join(root, file)
        relative_path = os.path.relpath(root, input_folder)
        bilateral_output_folder_path = os.path.join(bilateral_output_folder, relative_path)
        os.makedirs(bilateral_output_folder_path, exist_ok=True)

        # Leer la imagen
        image = cv2.imread(image_path)

        if image is None:
            print(f"No se pudo leer la imagen: {file}")
            continue

        # Aplicar el filtro bilateral
        bilateral = cv2.bilateralFilter(image, d=9, sigmaColor=75, sigmaSpace=75)

        # Guardar la imagen procesada
        bilateral_path = os.path.join(bilateral_output_folder_path, f"bilateral_{file}")
        cv2.imwrite(bilateral_path, bilateral)

        print(f"Processed and saved with bilateral filter: {file}")
# Out:
# Processed and saved with bilateral filter: 0100.jpeg
# Processed and saved with bilateral filter: 0102.jpeg
# Processed and saved with bilateral filter: 0105.png
# Processed and saved with bilateral filter: 0106.jpeg
# Processed and saved with bilateral filter: 0108.jpeg
# Processed and saved with bilateral filter: 0111.jpg
# Processed and saved with bilateral filter: 0112.jpg
# Processed and saved with bilateral filter: 0113.jpg
# Processed and saved with bilateral filter: 0115.jpeg
# Processed and saved with bilateral filter: 0118.jpeg
# Processed and saved with bilateral filter: 0119.jpeg
# Processed and saved with bilateral filter: 0120.jpg
# Processed and saved with bilateral filter: 094.png
# Processed and saved with bilateral filter: 096.png
# Processed and saved with bilateral filter: 098.jpeg
# Processed and saved with bilateral filter: auntminnie-2020_01_31_20_24_2322_2020_01_31_x-ray_coronavirus_US.jpg
# Processed and saved with bilateral filter: auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Processed and saved with bilateral filter: auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Processed and saved with bilateral filter: auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Processed and saved with bilateral filter: auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Processed and saved with bilateral filter: COVID-00003b.jpg
# Processed and saved with bilateral filter: COVID-00012.jpg
# Processed and saved with bilateral filter: COVID-00022.jpg
# Processed and saved with bilateral filter: COVID-00033.jpg
# Processed and saved with bilateral filter: COVID-00037.jpg
# Processed and saved with bilateral filter: radiopaedia-2019-novel-coronavirus-infected-pneumonia.jpg
# Processed and saved with bilateral filter: 0101.jpeg
# Processed and saved with bilateral filter: 0102.jpeg
# Processed and saved with bilateral filter: 0103.jpeg
# Processed and saved with bilateral filter: 0105.jpeg
# Processed and saved with bilateral filter: 0106.jpeg
# Processed and saved with bilateral filter: 0107.jpeg
# Processed and saved with bilateral filter: 0108.jpeg
# Processed and saved with bilateral filter: 0109.jpeg
# Processed and saved with bilateral filter: 0110.jpeg
# Processed and saved with bilateral filter: 0111.jpeg
# Processed and saved with bilateral filter: 072.jpeg
# Processed and saved with bilateral filter: 073.jpeg
# Processed and saved with bilateral filter: 074.jpeg
# Processed and saved with bilateral filter: 075.jpeg
# Processed and saved with bilateral filter: 076.jpeg
# Processed and saved with bilateral filter: 077.jpeg
# Processed and saved with bilateral filter: 078.jpeg
# Processed and saved with bilateral filter: 08.jpeg
# Processed and saved with bilateral filter: 081.jpeg
# Processed and saved with bilateral filter: 082.jpeg
# Processed and saved with bilateral filter: 083.jpeg
# Processed and saved with bilateral filter: 084.jpeg
# Processed and saved with bilateral filter: 09.jpeg
# Processed and saved with bilateral filter: 094.jpeg
# Processed and saved with bilateral filter: 095.jpeg
# Processed and saved with bilateral filter: 096.jpeg

# %% [markdown]
# ## Preparacion de las imagenes con filtro Canny para detectar bordes

# %%
# Crear la carpeta de salida si no existe
canny_output_folder = 'dataset/output/canny'
os.makedirs(canny_output_folder, exist_ok=True)

# Procesar cada imagen en la carpeta de entrada
for root, dirs, files in os.walk(input_folder):
    for file in files:
        image_path = os.path.join(root, file)
        relative_path = os.path.relpath(root, input_folder)
        canny_output_folder_path = os.path.join(canny_output_folder, relative_path)
        os.makedirs(canny_output_folder_path, exist_ok=True)

        # Leer la imagen
        image = cv2.imread(image_path)

        if image is None:
            print(f"No se pudo leer la imagen: {file}")
            continue

        # Convertir a escala de grises
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Aplicar el filtro Canny
        canny = cv2.Canny(gray, 100, 200)

        # Guardar la imagen procesada
        canny_path = os.path.join(canny_output_folder_path, f"canny_{file}")
        cv2.imwrite(canny_path, canny)

        print(f"Processed and saved with Canny filter: {file}")
# Out:
# Processed and saved with Canny filter: 0100.jpeg
# Processed and saved with Canny filter: 0102.jpeg
# Processed and saved with Canny filter: 0105.png
# Processed and saved with Canny filter: 0106.jpeg
# Processed and saved with Canny filter: 0108.jpeg
# Processed and saved with Canny filter: 0111.jpg
# Processed and saved with Canny filter: 0112.jpg
# Processed and saved with Canny filter: 0113.jpg
# Processed and saved with Canny filter: 0115.jpeg
# Processed and saved with Canny filter: 0118.jpeg
# Processed and saved with Canny filter: 0119.jpeg
# Processed and saved with Canny filter: 0120.jpg
# Processed and saved with Canny filter: 094.png
# Processed and saved with Canny filter: 096.png
# Processed and saved with Canny filter: 098.jpeg
# Processed and saved with Canny filter: auntminnie-2020_01_31_20_24_2322_2020_01_31_x-ray_coronavirus_US.jpg
# Processed and saved with Canny filter: auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Processed and saved with Canny filter: auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Processed and saved with Canny filter: auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Processed and saved with Canny filter: auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Processed and saved with Canny filter: COVID-00003b.jpg
# Processed and saved with Canny filter: COVID-00012.jpg
# Processed and saved with Canny filter: COVID-00022.jpg
# Processed and saved with Canny filter: COVID-00033.jpg
# Processed and saved with Canny filter: COVID-00037.jpg
# Processed and saved with Canny filter: radiopaedia-2019-novel-coronavirus-infected-pneumonia.jpg
# Processed and saved with Canny filter: 0101.jpeg
# Processed and saved with Canny filter: 0102.jpeg
# Processed and saved with Canny filter: 0103.jpeg
# Processed and saved with Canny filter: 0105.jpeg
# Processed and saved with Canny filter: 0106.jpeg
# Processed and saved with Canny filter: 0107.jpeg
# Processed and saved with Canny filter: 0108.jpeg
# Processed and saved with Canny filter: 0109.jpeg
# Processed and saved with Canny filter: 0110.jpeg
# Processed and saved with Canny filter: 0111.jpeg
# Processed and saved with Canny filter: 0112.jpeg
# Processed and saved with Canny filter: 0114.jpeg
# Processed and saved with Canny filter: 0115.jpeg
# Processed and saved with Canny filter: 0116.jpeg
# Processed and saved with Canny filter: 0117.jpeg
# Processed and saved with Canny filter: 0118.jpeg
# Processed and saved with Canny filter: 0119.jpeg
# Processed and saved with Canny filter: 0120.jpeg
# Processed and saved with Canny filter: 0121.jpeg
# Processed and saved with Canny filter: 0122.jpeg
# Processed and saved with Canny filter: 0101.jpeg
# Processed and saved with Canny filter: 0102.jpeg
# Processed and saved with Canny filter: 0103.jpeg
# Processed and saved with Canny filter: 0104.jpeg
# Processed and saved with Canny filter: 0105.jpeg
# Processed and saved with Canny filter: 0106.jpeg
# Processed and saved with Canny filter: 0107.jpeg
# Processed and saved with Canny filter: 0108.jpeg
# Processed and saved with Canny filter: 0109.jpeg
# Processed and saved with Canny filter: 0110.jpeg
# Processed and saved with Canny filter: 0111.jpeg
# Processed and saved with Canny filter: 0112.jpeg
# Processed and saved with Canny filter: 0113.jpeg
# Processed and saved with Canny filter: 0114.jpeg
# Processed and saved with Canny filter: 0115.jpeg
# Processed and saved with Canny filter: 0116.jpeg
# Processed and saved with Canny filter: 0117.jpeg
# Processed and saved with Canny filter: 0118.jpeg
# Processed and saved with Canny filter: 0119.jpeg
# Processed and saved with Canny filter: 0120.jpeg
# Processed and saved with Canny filter: 01.jpeg
# Processed and saved with Canny filter: 010.png
# Processed and saved with Canny filter: 012.jpeg
# Processed and saved with Canny filter: 015.jpg
# Processed and saved with Canny filter: 019.png
# Processed and saved with Canny filter: 02.jpeg
# Processed and saved with Canny filter: 020.jpg
# Processed and saved with Canny filter: 021.jpeg
# Processed and saved with Canny filter: 022.jpeg
# Processed and saved with Canny filter: 024.jpeg
# Processed and saved with Canny filter: 025.jpeg
# Processed and saved with Canny filter: 026.jpeg
# Processed and saved with Canny filter: 027.jpeg
# Processed and saved with Canny filter: 03.jpeg
# Processed and saved with Canny filter: 031.jpeg
# Processed and saved with Canny filter: 032.jpeg
# Processed and saved with Canny filter: 033.png
# Processed and saved with Canny filter: 039.jpeg
# Processed and saved with Canny filter: 04.png
# Processed and saved with Canny filter: 040.jpeg
# Processed and saved with Canny filter: 041.jpeg
# Processed and saved with Canny filter: 042.jpeg
# Processed and saved with Canny filter: 043.jpeg
# Processed and saved with Canny filter: 044.jpeg
# Processed and saved with Canny filter: 045.jpeg
# Processed and saved with Canny filter: 046.jpeg
# Processed and saved with Canny filter: 047.jpeg
# Processed and saved with Canny filter: 048.jpeg
# Processed and saved with Canny filter: 049.jpeg
# Processed and saved with Canny filter: 050.jpeg
# Processed and saved with Canny filter: 051.jpeg
# Processed and saved with Canny filter: 052.jpeg
# Processed and saved with Canny filter: 053.jpeg
# Processed and saved with Canny filter: 054.jpeg
# Processed and saved with Canny filter: 055.jpeg
# Processed and saved with Canny filter: 056.jpg
# Processed and saved with Canny filter: 057.jpeg
# Processed and saved with Canny filter: 058.jpeg
# Processed and saved with Canny filter: 059.jpeg
# Processed and saved with Canny filter: 06.jpeg
# Processed and saved with Canny filter: 060.jpeg
# Processed and saved with Canny filter: 061.jpg
# Processed and saved with Canny filter: 062.jpeg
# Processed and saved with Canny filter: 064.jpg
# Processed and saved with Canny filter: 065.jpeg
# Processed and saved with Canny filter: 067.jpg
# Processed and saved with Canny filter: 068.jpg
# Processed and saved with Canny filter: 069.jpg
# Processed and saved with Canny filter: 07.jpg
# Processed and saved with Canny filter: 071.jpg
# Processed and saved with Canny filter: 072.jpeg
# Processed and saved with Canny filter: 073.jpg
# Processed and saved with Canny filter: 074.jpg
# Processed and saved with Canny filter: 076.jpg
# Processed and saved with Canny filter: 078.jpeg
# Processed and saved with Canny filter: 079.jpeg
# Processed and saved with Canny filter: 08.jpeg
# Processed and saved with Canny filter: 080.jpg
# Processed and saved with Canny filter: 081.jpeg
# Processed and saved with Canny filter: 082.jpg
# Processed and saved with Canny filter: 083.jpeg
# Processed and saved with Canny filter: 084.jpeg
# Processed and saved with Canny filter: 085.jpeg
# Processed and saved with Canny filter: 086.jpg
# Processed and saved with Canny filter: 088.jpeg
# Processed and saved with Canny filter: 089.jpg
# Processed and saved with Canny filter: 09.png
# Processed and saved with Canny filter: 090.jpeg
# Processed and saved with Canny filter: 091.jpg
# Processed and saved with Canny filter: 092.png
# Processed and saved with Canny filter: COVID-00001.jpg
# Processed and saved with Canny filter: COVID-00002.jpg
# Processed and saved with Canny filter: COVID-00003a.jpg
# Processed and saved with Canny filter: COVID-00003b.jpg
# Processed and saved with Canny filter: COVID-00004.jpg
# Processed and saved with Canny filter: COVID-00005.jpg
# Processed and saved with Canny filter: COVID-00006.jpg
# Processed and saved with Canny filter: COVID-00007.jpg
# Processed and saved with Canny filter: COVID-00008.jpg
# Processed and saved with Canny filter: COVID-00009.jpg
# Processed and saved with Canny filter: COVID-00010.jpg
# Processed and saved with Canny filter: COVID-00011.jpg
# Processed and saved with Canny filter: COVID-00012.jpg
# Processed and saved with Canny filter: COVID-00013a.jpg
# Processed and saved with Canny filter: COVID-00013b.jpg
# Processed and saved with Canny filter: COVID-00014.jpg
# Processed and saved with Canny filter: COVID-00015a.png
# Processed and saved with Canny filter: COVID-00015b.png
# Processed and saved with Canny filter: COVID-00016.jpg
# Processed and saved with Canny filter: COVID-00017.jpg
# Processed and saved with Canny filter: COVID-00018.jpg
# Processed and saved with Canny filter: COVID-00019.jpg
# Processed and saved with Canny filter: COVID-00020.jpg
# Processed and saved with Canny filter: COVID-00021.jpg
# Processed and saved with Canny filter: COVID-00022.jpg
# Processed and saved with Canny filter: COVID-00023.jpg
# Processed and saved with Canny filter: COVID-00024.jpg
# Processed and saved with Canny filter: COVID-00025.jpg
# Processed and saved with Canny filter: COVID-00026.jpg
# Processed and saved with Canny filter: COVID-00027.jpg
# Processed and saved with Canny filter: COVID-00028.jpg
# Processed and saved with Canny filter: COVID-00029.jpg
# Processed and saved with Canny filter: COVID-00030.jpg
# Processed and saved with Canny filter: COVID-00031.jpg
# Processed and saved with Canny filter: COVID-00032.jpg
# Processed and saved with Canny filter: COVID-00033.jpg
# Processed and saved with Canny filter: COVID-00034.jpg
# Processed and saved with Canny filter: COVID-00035.jpg
# Processed and saved with Canny filter: COVID-00036.jpg
# Processed and saved with Canny filter: COVID-00037.jpg
# Processed and saved with Canny filter: COVID-00038.jpg
# Processed and saved with Canny filter: 01.jpeg
# Processed and saved with Canny filter: 010.jpeg
# Processed and saved with Canny filter: 011.jpeg
# Processed and saved with Canny filter: 012.jpeg
# Processed and saved with Canny filter: 013.jpeg
# Processed and saved with Canny filter: 014.jpeg
# Processed and saved with Canny filter: 015.jpeg
# Processed and saved with Canny filter: 016.jpeg
# Processed and saved with Canny filter: 017.jpeg
# Processed and saved with Canny filter: 018.jpeg
# Processed and saved with Canny filter: 019.jpeg
# Processed and saved with Canny filter: 02.jpeg
# Processed and saved with Canny filter: 020.jpeg
# Processed and saved with Canny filter: 021.jpeg
# Processed and saved with Canny filter: 022.jpeg
# Processed and saved with Canny filter: 023.jpeg
# Processed and saved with Canny filter: 024.jpeg
# Processed and saved with Canny filter: 025.jpeg
# Processed and saved with Canny filter: 03.jpeg
# Processed and saved with Canny filter: 04.jpeg
# Processed and saved with Canny filter: 05.jpeg
# Processed and saved with Canny filter: 050.jpeg
# Processed and saved with Canny filter: 051.jpeg
# Processed and saved with Canny filter: 052.jpeg
# Processed and saved with Canny filter: 053.jpeg
# Processed and saved with Canny filter: 054.jpeg
# Processed and saved with Canny filter: 055.jpeg
# Processed and saved with Canny filter: 056.jpeg
# Processed and saved with Canny filter: 057.jpeg
# Processed and saved with Canny filter: 058.jpeg
# Processed and saved with Canny filter: 059.jpeg
# Processed and saved with Canny filter: 06.jpeg
# Processed and saved with Canny filter: 060.jpeg
# Processed and saved with Canny filter: 061.jpeg
# Processed and saved with Canny filter: 062.jpeg
# Processed and saved with Canny filter: 063.jpeg
# Processed and saved with Canny filter: 064.jpeg
# Processed and saved with Canny filter: 065.jpeg
# Processed and saved with Canny filter: 066.jpeg
# Processed and saved with Canny filter: 067.jpeg
# Processed and saved with Canny filter: 068.jpeg
# Processed and saved with Canny filter: 069.jpeg
# Processed and saved with Canny filter: 07.jpeg
# Processed and saved with Canny filter: 070.jpeg
# Processed and saved with Canny filter: 071.jpeg
# Processed and saved with Canny filter: 072.jpeg
# Processed and saved with Canny filter: 073.jpeg
# Processed and saved with Canny filter: 074.jpeg
# Processed and saved with Canny filter: 075.jpeg
# Processed and saved with Canny filter: 076.jpeg
# Processed and saved with Canny filter: 077.jpeg
# Processed and saved with Canny filter: 079.jpeg
# Processed and saved with Canny filter: 08.jpeg
# Processed and saved with Canny filter: 080.jpeg
# Processed and saved with Canny filter: 081.jpeg
# Processed and saved with Canny filter: 082.jpeg
# Processed and saved with Canny filter: 083.jpeg
# Processed and saved with Canny filter: 084.jpeg
# Processed and saved with Canny filter: 085.jpeg
# Processed and saved with Canny filter: 086.jpeg
# Processed and saved with Canny filter: 08.jpeg
# Processed and saved with Canny filter: 081.jpeg
# Processed and saved with Canny filter: 082.jpeg
# Processed and saved with Canny filter: 083.jpeg
# Processed and saved with Canny filter: 084.jpeg
# Processed and saved with Canny filter: 09.jpeg
# Processed and saved with Canny filter: 094.jpeg
# Processed and saved with Canny filter: 095.jpeg
# Processed and saved with Canny filter: 096.jpeg

# %% [markdown]
# ### Data Augmentation

# %%
import cv2
import os
import numpy as np

# Definir las rutas de la carpeta de entrada (donde están las imágenes) y la de salida (donde se guardarán las imágenes aumentadas)

#input_folder = 'dataset/output/raw'  # Ruta de la carpeta Raw
#input_folder = 'dataset/output/bilateral'  # Ruta de la carpeta Bilateral
input_folder = 'dataset/output/canny'  # Ruta de la carpeta Canny

#output_folder = 'dataset/augmented/raw'  # Ruta de la carpeta donde se guardarán las imágenes aumentadas
#output_folder = 'dataset/augmented/bilateral'  # Ruta de la carpeta donde se guardarán las imágenes aumentadas
output_folder = 'dataset/augmented/canny'  # Ruta de la carpeta donde se guardarán las imágenes aumentadas

# Crear la carpeta de salida si no existe
os.makedirs(output_folder, exist_ok=True)

# Funciones de aumento de datos
def augment_image(image):
    augmented = []

    # Rotaciones: 90°, 180°, 270°
    rows, cols = image.shape[:2]
    for angle in [90, 180, 270]:
        M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)
        rotated = cv2.warpAffine(image, M, (cols, rows))
        augmented.append(rotated)

    # Escalado: 0.5x y 1.5x
    for scale in [0.5, 1.5]:
        scaled = cv2.resize(image, None, fx=scale, fy=scale, interpolation=cv2.INTER_LINEAR)
        augmented.append(scaled)

    # Traslaciones: izquierda, derecha, arriba, abajo
    for dx, dy in [(-50, 0), (50, 0), (0, -50), (0, 50)]:
        M = np.float32([[1, 0, dx], [0, 1, dy]])
        translated = cv2.warpAffine(image, M, (cols, rows))
        augmented.append(translated)

    # Volteos: horizontal, vertical
    augmented.append(cv2.flip(image, 1))  # Volteo horizontal
    augmented.append(cv2.flip(image, 0))  # Volteo vertical

    # Filtro adicional: Escala de grises
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convertir a escala de grises
    augmented.append(cv2.cvtColor(gray, cv2.COLOR_GRAY2BGR))  # Convertir a formato 3 canales para guardar

    return augmented

# Procesar imágenes y aplicar aumento de datos
for root, dirs, files in os.walk(input_folder):
    for file in files:
        try:
            # Leer la imagen desde la carpeta local
            image_path = os.path.join(root, file)
            image = cv2.imread(image_path)

            if image is None:
                print(f"No se pudo leer la imagen: {file}")
                continue

            # Aplicar las transformaciones
            augmented_images = augment_image(image)

            # Crear la estructura de carpetas en la carpeta de salida
            relative_path = os.path.relpath(root, input_folder)
            output_folder_path = os.path.join(output_folder, relative_path)
            os.makedirs(output_folder_path, exist_ok=True)

            # Guardar las imágenes aumentadas
            base_name = os.path.splitext(file)[0]
            for i, aug_image in enumerate(augmented_images):
                output_path = os.path.join(output_folder_path, f"{base_name}_aug_{i+1}.jpg")
                cv2.imwrite(output_path, aug_image)

            print(f"Procesamiento completo para: {file}, {len(augmented_images)} imágenes generadas.")
        except Exception as e:
            print(f"Error procesando {file}: {e}")

# Verificar si la carpeta tiene imágenes
if len(os.listdir(output_folder)) == 0:
    print("La carpeta de imágenes aumentadas está vacía. Verifica el proceso de escritura.")
else:
    print(f"Imágenes aumentadas guardadas en: {output_folder}")
# Out:
# Procesamiento completo para: bilateral_0100.jpeg, 12 imágenes generadas.
# Procesamiento completo para: bilateral_